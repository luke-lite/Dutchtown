# %%
import sqlite3
import pandas as pd

# %%
prcl_sales = pd.read_csv('housing_data/PrclSales.csv')

# %%
prcl_sales['year']
# Out:
#         CityBlock  Parcel  OwnerCode  SaleNum  AsrParcelId  SaleType  \
# 0            14.0      20          0        1    149020000        99
# 1            15.0      60          0        1    159060000        99
# 2            15.0      90          0      101    159090000         0
# 3            16.0      20          0        1    169020000        98
# 4            16.0      20          0        2    169020000        61
# ...           ...     ...        ...      ...          ...       ...
# 174640     9120.0     380          0      101  91209380000         0
# 174641     9121.0      10          0        1  91219010000        42
# 174642     9121.0      10          0        2  91219010000        98
# 174643     9121.0      31          0      101  91219031000        61
# 174644     9121.0      31          0      102  91219031000         0
#
#           SaleDate  SalePrice  LRMSSaleDate
# 0        7/12/2005   485000.0           NaN
# 1        5/12/2006  1375000.0           NaN
# ...

# %%
prcl_sales['sale_year'] = prcl_sales['SaleDate'].str[-4:]

# %%
prcl_sales[prcl_sales['sale_year'] == '2022']
# Out:
#         CityBlock  Parcel  OwnerCode  SaleNum  AsrParcelId  SaleType  \
# 18           26.0      10          0      101    269010000         0
# 25           41.0     120          0      101    419120000         0
# 29           49.0      15          0      101    499015000         0
# 30           49.0      80          0      101    499080000         0
# 31           49.0      80          0      102    499080000         0
# ...           ...     ...        ...      ...          ...       ...
# 174535     9097.0      20          0      101  90979020000        10
# 174542     9097.0      92          0      101  90979092000        61
# 174574     9104.0      20          0      101  91049020000         0
# 174586     9111.0      70          0      101  91119070000        40
# 174644     9121.0      31          0      102  91219031000         0
#
#           SaleDate  SalePrice  LRMSSaleDate sale_year
# 18        1/4/2022  1200000.0           NaN      2022
# ...

# %%
prcl_sales
# Out:
#         CityBlock  Parcel  OwnerCode  SaleNum  AsrParcelId  SaleType  \
# 0            14.0      20          0        1    149020000        99
# 1            15.0      60          0        1    159060000        99
# 2            15.0      90          0      101    159090000         0
# 3            16.0      20          0        1    169020000        98
# 4            16.0      20          0        2    169020000        61
# ...           ...     ...        ...      ...          ...       ...
# 174640     9120.0     380          0      101  91209380000         0
# 174641     9121.0      10          0        1  91219010000        42
# 174642     9121.0      10          0        2  91219010000        98
# 174643     9121.0      31          0      101  91219031000        61
# 174644     9121.0      31          0      102  91219031000         0
#
#           SaleDate  SalePrice  LRMSSaleDate sale_year
# 0        7/12/2005   485000.0           NaN      2005
# ...

# %%
cdcbps = pd.read_csv('housing_data/CdCityBlockPartSrc.csv')

# %%
cdcbps
# Out:
#   CityBlockPartSrc                              Desc
# 0                A               Prior manual update
# 1                C  From CorBlock if non-split Block
# 2                L            From Prcl via PrclLink
# 3                P                         From Prcl
# 4                U                     Manual update
