# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## OG CSV Adjustments:

# %%
# old_nibrs_df = pd.read_csv('crime_data/nibrs_thru_dec_2023.csv')
# old_nibrs_df

# %%
# df = old_nibrs_df
# df = df.drop(['nibrs_grp', 'beat', 'city', 'state', 'zip'], axis=1)
# df.rename(columns={'inci_id':'IncidentNum', 'date_inc':'IncidentDate', 'time_inc':'TimeOccurred', 'offense':'SLMPDOffense',
#                    'nibrs_code':'NIBRSCode', 'district': 'District', 'neighborhood': 'Neighborhood', 'latitude':'Latitude',
#                    'longitude':'Longitude', 'incidentlocation':'PrimaryLocation', 'locationStreet2_Apt':'SecondaryLocation'}, inplace=True)

# float_cols = ['UCR_SRS', 'VictimNum']
# str_cols = ['IncidentDate', 'TimeOccured', 'SupplementDate', 'NIBRSCat',
#             'NIBRSOffenseType', 'CrimeGrade', 'NeighborhoodNum', 'IncidentNature']
# bool_cols = ['Supplemented', 'FirearmUsed']
# datetime_cols = ['IncidentDate', 'TimeOccured', 'SupplementDate']

# for column in float_cols:
#     if column in df.columns:
#         df[column] = df[column].astype('float')
#     else:
#         df[column] = np.nan
# for column in str_cols:
#     if column in df.columns:
#         df[column] = df[column].astype('str')
#     else:
#         df[column] = None
# for column in bool_cols:
#     if column in df.columns:
#         df[column] = df[column].astype('bool')
#     else:
#         df[column] = None

# df

# %%
# ordered_cols = ['IncidentNum', 'IncidentDate', 'TimeOccurred', 'SLMPDOffense',
#                 'NIBRSCode', 'NIBRSCat', 'NIBRSOffenseType', 'UCR_SRS', 'CrimeGrade',
#                 'PrimaryLocation', 'SecondaryLocation', 'District', 'Neighborhood',
#                 'NeighborhoodNum', 'Latitude', 'Longitude', 'Supplemented',
#                 'SupplementDate', 'VictimNum', 'FirearmUsed', 'IncidentNature']
# df = df[ordered_cols]
# df

# %%
# df.info()

# %%
# df.to_csv('crime_data/Crime2021-2023.csv', index=False)

# %% [markdown]
# ## Monthly CSV Adjustments:

# %%
class NewDataPrep(csv_loc):
    df = pd.read_csv(csv_loc)
    df = df.drop('IncidentTopSRS_UCR', axis=1)
    df.rename(columns={'CrimeAgainst': 'NIBRSCat',
                       'NIBRS': 'NIBRSCode',
                       'NIBRSCategory':'NIBRSOffenseType',
                       'SRS_UCR':'UCR_SRS',
                       'OccurredFromTime':'TimeOccurred',
                       'Offense':'SLMPDOffense',
                       'FelMisdCit':'CrimeGrade',
                       'IncidentLocation':'PrimaryLocation',
                       'IntersectionOtherLoc':'SecondaryLocation',
                       'NbhdNum':'NeighborhoodNum',
                       'IncidentSupplemented':'Supplemented',
                       'LastSuppDate':'SupplementDate'}, inplace=True)
    
    ordered_cols = ['IncidentNum', 'IncidentDate', 'TimeOccurred', 'SLMPDOffense',
                    'NIBRSCode', 'NIBRSCat', 'NIBRSOffenseType', 'UCR_SRS', 'CrimeGrade',
                    'PrimaryLocation', 'SecondaryLocation', 'District', 'Neighborhood',
                    'NeighborhoodNum', 'Latitude', 'Longitude', 'Supplemented',
                    'SupplementDate', 'VictimNum', 'FirearmUsed', 'IncidentNature']
    df = df[ordered_cols]
    
    supp_df = df[df['Supplemented'] == 'Yes']
    unfound_df = df[(df['Supplemented'].isna()) & (df['SLMPDOffense'] == 'UNFOUNDED INCIDENT')]
    new_df = df[df['Supplemented'] == 'No']

    if len(df) != len(supp_df) + len(unfound_df) + len(new_df):
        raise Exception("Something doesn't add up")

# %%
jan_df = pd.read_csv('crime_data/crimeJanuary2024.csv')
jan_df
# Out:
#      IncidentDate OccurredFromTime  IncidentNum  \
# 0      2020-12-17         18:00:00     20056840
# 1      2020-12-17         18:00:00     20056840
# 2      2020-12-23         06:05:00     20057591
# 3      2020-12-29         00:52:00     20058325
# 4      2020-12-31         22:20:00     20058746
# ...           ...              ...          ...
# 5870   2024-01-25         12:00:00     24007184
# 5871   2024-01-31         00:01:00     24007205
# 5872   2024-01-26         11:00:00     24007385
# 5873   2024-01-22         12:00:00     24007544
# 5874   2024-01-29         07:29:00     24007571
#
#                                             Offense NIBRS  \
# 0                           STEALING - $750 OR MORE   23H
# 1                        PROPERTY DAMAGE 1ST DEGREE   290
# 2                              ROBBERY - 1ST DEGREE   120
# 3                              ROBBERY - 1ST DEGREE   120
# 4                     ASSAULT 1ST DEGREE OR ATTEMPT   13A
# ...                                             ...   ...
# 5870    STEALING UNDER $150 (PETTY LARCENY - OTHER)   23H
# 5871  DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)   290
# 5872                                       STEALING   23D
# 5873  LEAVING THE SCENE OF A MOTOR VEHICLE ACCIDENT   90Z
# 5874    STEALING UNDER $150 (PETTY LARCENY - OTHER)   23H
#
#                                  NIBRSCategory  SRS_UCR CrimeAgainst  \
# 0                            All Other Larceny      6.0     Property
# 1     Destruction/Damage/Vandalism of Property      NaN     Property
# 2                                      Robbery      3.0     Property
# 3                                      Robbery      3.0     Property
# 4                           Aggravated Assault      4.0       Person
# ...                                        ...      ...          ...
# 5870                         All Other Larceny      6.0     Property
# 5871  Destruction/Damage/Vandalism of Property      NaN     Property
# 5872                       Theft From Building      6.0     Property
# 5873                        All Other Offenses      NaN  Unspecified
# 5874                         All Other Larceny      6.0     Property
#
#      FelMisdCit  IncidentTopSRS_UCR     IncidentLocation IntersectionOtherLoc  \
# 0             F                 6.0      8025 S BROADWAY                  NaN
# 1           NaN                 6.0      8025 S BROADWAY                  NaN
# 2           NaN                 3.0       2600 N 14TH ST                  NaN
# 3           NaN                 3.0     4922 CLAXTON AVE                  NaN
# 4           NaN                 4.0        811 SPRUCE ST             ROOM 311
# ...         ...                 ...                  ...                  ...
# 5870        NaN                 6.0   5118 WATERMAN BLVD                  NaN
# 5871        NaN                 NaN      7208 N BROADWAY                  NaN
# 5872          F                 6.0  4021 LACLEDE AVENUE                  NaN
# 5873        NaN                 NaN   6014 MARMADUKE AVE                  NaN
# 5874        NaN                 6.0          ACADEMY AVE            PAGE BLVD
#
#       District        Neighborhood NbhdNum   Latitude  Longitude  \
# 0          1.0               Patch       2  38.544389 -90.262290
# 1          1.0               Patch       2  38.544389 -90.262290
# 2          4.0  Old North St Louis      63  38.650037 -90.196741
# 3          6.0          Mark Twain      71  38.689941 -90.249730
# 4          4.0            Downtown      35  38.623713 -90.194768
# ...        ...                 ...     ...        ...        ...
# 5870       5.0    Central West End      38  38.648258 -90.268370
# 5871       6.0    North Riverfront      79  38.631053 -90.187720
# 5872       5.0    Central West End      38  38.637080 -90.244946
# 5873       2.0     Clifton Heights      11  38.609736 -90.290430
# 5874       5.0             Academy      51  38.657860 -90.266113
#
#      IncidentSupplemented                 LastSuppDate  VictimNum FirearmUsed  \
# 0                     Yes  2024-01-29 08:55:56.3400000        NaN          No
# 1                     Yes  2024-01-29 08:55:56.3400000        NaN          No
# 2                     Yes  2024-01-27 00:05:05.7070000        NaN         Yes
# 3                     Yes  2024-01-12 13:47:31.0000000        NaN         Yes
# 4                     Yes  2024-01-08 08:33:09.0300000   363565.0         Yes
# ...                   ...                          ...        ...         ...
# 5870                   No                          NaN        NaN          No
# 5871                   No                          NaN        NaN          No
# 5872                   No                          NaN        NaN          No
# 5873                   No                          NaN        NaN          No
# 5874                   No                          NaN        NaN          No
#
#                                 IncidentNature
# 0                   Stolen Property - Criminal
# 1                   Stolen Property - Criminal
# 2                        Carjacking - Criminal
# 3                           Robbery - Criminal
# 4     Aggravated Assault - Shooting - Criminal
# ...                                        ...
# 5870                        Larceny - Criminal
# 5871        Destruction of Property - Criminal
# 5872                        Larceny - Criminal
# 5873           Offenses - All Other - Criminal
# 5874                        Larceny - Criminal
#
# [5875 rows x 22 columns]

# %%
jan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IncidentDate          5875 non-null   object
#  1   OccurredFromTime      5837 non-null   object
#  2   IncidentNum           5875 non-null   int64
#  3   Offense               5875 non-null   object
#  4   NIBRS                 5837 non-null   object
#  5   NIBRSCategory         5837 non-null   object
#  6   SRS_UCR               2343 non-null   float64
#  7   CrimeAgainst          5837 non-null   object
#  8   FelMisdCit            4161 non-null   object
#  9   IncidentTopSRS_UCR    3277 non-null   float64
#  10  IncidentLocation      5837 non-null   object
#  11  IntersectionOtherLoc  906 non-null    object
#  12  District              5837 non-null   float64
#  13  Neighborhood          5837 non-null   object
#  14  NbhdNum               5837 non-null   object
#  15  Latitude              5818 non-null   float64
#  16  Longitude             5818 non-null   float64
#  17  IncidentSupplemented  5837 non-null   object
#  18  LastSuppDate          3802 non-null   object
#  19  VictimNum             1086 non-null   float64
#  20  FirearmUsed           5837 non-null   object
#  21  IncidentNature        5837 non-null   object
# dtypes: float64(6), int64(1), object(15)
# memory usage: 1009.9+ KB

# %%
df = jan_df
df = df.drop('IncidentTopSRS_UCR', axis=1)
df.rename(columns={'CrimeAgainst': 'NIBRSCat',
                   'NIBRS': 'NIBRSCode',
                   'NIBRSCategory':'NIBRSOffenseType',
                   'SRS_UCR':'UCR_SRS',
                   'OccurredFromTime':'TimeOccurred',
                   'Offense':'SLMPDOffense',
                   'FelMisdCit':'CrimeGrade',
                   'IncidentLocation':'PrimaryLocation',
                   'IntersectionOtherLoc':'SecondaryLocation',
                   'NbhdNum':'NeighborhoodNum',
                   'IncidentSupplemented':'Supplemented',
                   'LastSuppDate':'SupplementDate'}, inplace=True)

ordered_cols = ['IncidentNum', 'IncidentDate', 'TimeOccurred', 'SLMPDOffense',
                'NIBRSCode', 'NIBRSCat', 'NIBRSOffenseType', 'UCR_SRS', 'CrimeGrade',
                'PrimaryLocation', 'SecondaryLocation', 'District', 'Neighborhood',
                'NeighborhoodNum', 'Latitude', 'Longitude', 'Supplemented',
                'SupplementDate', 'VictimNum', 'FirearmUsed', 'IncidentNature']
df = df[ordered_cols]
df
# Out:
#       IncidentNum IncidentDate TimeOccurred  \
# 0        20056840   2020-12-17     18:00:00
# 1        20056840   2020-12-17     18:00:00
# 2        20057591   2020-12-23     06:05:00
# 3        20058325   2020-12-29     00:52:00
# 4        20058746   2020-12-31     22:20:00
# ...           ...          ...          ...
# 5870     24007184   2024-01-25     12:00:00
# 5871     24007205   2024-01-31     00:01:00
# 5872     24007385   2024-01-26     11:00:00
# 5873     24007544   2024-01-22     12:00:00
# 5874     24007571   2024-01-29     07:29:00
#
#                                        SLMPDOffense NIBRSCode     NIBRSCat  \
# 0                           STEALING - $750 OR MORE       23H     Property
# 1                        PROPERTY DAMAGE 1ST DEGREE       290     Property
# 2                              ROBBERY - 1ST DEGREE       120     Property
# 3                              ROBBERY - 1ST DEGREE       120     Property
# 4                     ASSAULT 1ST DEGREE OR ATTEMPT       13A       Person
# ...                                             ...       ...          ...
# 5870    STEALING UNDER $150 (PETTY LARCENY - OTHER)       23H     Property
# 5871  DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290     Property
# 5872                                       STEALING       23D     Property
# 5873  LEAVING THE SCENE OF A MOTOR VEHICLE ACCIDENT       90Z  Unspecified
# 5874    STEALING UNDER $150 (PETTY LARCENY - OTHER)       23H     Property
#
#                               NIBRSOffenseType  UCR_SRS CrimeGrade  \
# 0                            All Other Larceny      6.0          F
# 1     Destruction/Damage/Vandalism of Property      NaN        NaN
# 2                                      Robbery      3.0        NaN
# 3                                      Robbery      3.0        NaN
# 4                           Aggravated Assault      4.0        NaN
# ...                                        ...      ...        ...
# 5870                         All Other Larceny      6.0        NaN
# 5871  Destruction/Damage/Vandalism of Property      NaN        NaN
# 5872                       Theft From Building      6.0          F
# 5873                        All Other Offenses      NaN        NaN
# 5874                         All Other Larceny      6.0        NaN
#
#           PrimaryLocation SecondaryLocation  District        Neighborhood  \
# 0         8025 S BROADWAY               NaN       1.0               Patch
# 1         8025 S BROADWAY               NaN       1.0               Patch
# 2          2600 N 14TH ST               NaN       4.0  Old North St Louis
# 3        4922 CLAXTON AVE               NaN       6.0          Mark Twain
# 4           811 SPRUCE ST          ROOM 311       4.0            Downtown
# ...                   ...               ...       ...                 ...
# 5870   5118 WATERMAN BLVD               NaN       5.0    Central West End
# 5871      7208 N BROADWAY               NaN       6.0    North Riverfront
# 5872  4021 LACLEDE AVENUE               NaN       5.0    Central West End
# 5873   6014 MARMADUKE AVE               NaN       2.0     Clifton Heights
# 5874          ACADEMY AVE         PAGE BLVD       5.0             Academy
#
#      NeighborhoodNum   Latitude  Longitude Supplemented  \
# 0                  2  38.544389 -90.262290          Yes
# 1                  2  38.544389 -90.262290          Yes
# 2                 63  38.650037 -90.196741          Yes
# 3                 71  38.689941 -90.249730          Yes
# 4                 35  38.623713 -90.194768          Yes
# ...              ...        ...        ...          ...
# 5870              38  38.648258 -90.268370           No
# 5871              79  38.631053 -90.187720           No
# 5872              38  38.637080 -90.244946           No
# 5873              11  38.609736 -90.290430           No
# 5874              51  38.657860 -90.266113           No
#
#                    SupplementDate  VictimNum FirearmUsed  \
# 0     2024-01-29 08:55:56.3400000        NaN          No
# 1     2024-01-29 08:55:56.3400000        NaN          No
# 2     2024-01-27 00:05:05.7070000        NaN         Yes
# 3     2024-01-12 13:47:31.0000000        NaN         Yes
# 4     2024-01-08 08:33:09.0300000   363565.0         Yes
# ...                           ...        ...         ...
# 5870                          NaN        NaN          No
# 5871                          NaN        NaN          No
# 5872                          NaN        NaN          No
# 5873                          NaN        NaN          No
# 5874                          NaN        NaN          No
#
#                                 IncidentNature
# 0                   Stolen Property - Criminal
# 1                   Stolen Property - Criminal
# 2                        Carjacking - Criminal
# 3                           Robbery - Criminal
# 4     Aggravated Assault - Shooting - Criminal
# ...                                        ...
# 5870                        Larceny - Criminal
# 5871        Destruction of Property - Criminal
# 5872                        Larceny - Criminal
# 5873           Offenses - All Other - Criminal
# 5874                        Larceny - Criminal
#
# [5875 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IncidentNum        5875 non-null   int64
#  1   IncidentDate       5875 non-null   object
#  2   TimeOccurred       5837 non-null   object
#  3   SLMPDOffense       5875 non-null   object
#  4   NIBRSCode          5837 non-null   object
#  5   NIBRSCat           5837 non-null   object
#  6   NIBRSOffenseType   5837 non-null   object
#  7   UCR_SRS            2343 non-null   float64
#  8   CrimeGrade         4161 non-null   object
#  9   PrimaryLocation    5837 non-null   object
#  10  SecondaryLocation  906 non-null    object
#  11  District           5837 non-null   float64
#  12  Neighborhood       5837 non-null   object
#  13  NeighborhoodNum    5837 non-null   object
#  14  Latitude           5818 non-null   float64
#  15  Longitude          5818 non-null   float64
#  16  Supplemented       5837 non-null   object
#  17  SupplementDate     3802 non-null   object
#  18  VictimNum          1086 non-null   float64
#  19  FirearmUsed        5837 non-null   object
#  20  IncidentNature     5837 non-null   object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 964.0+ KB

# %%
supp_df = df[df['Supplemented'] == 'Yes']
supp_df[supp_df['IncidentNum'] == 21000908]
# Out:
#     IncidentNum IncidentDate TimeOccurred  \
# 9      21000908   2021-01-06     19:14:00
# 10     21000908   2021-01-06     19:14:00
# 11     21000908   2021-01-06     19:14:00
# 12     21000908   2021-01-06     19:14:00
#
#                                          SLMPDOffense NIBRSCode NIBRSCat  \
# 9   ASSAULT 1ST DEGREE OR ATTEMPT - SERIOUS PHYSIC...       13A   Person
# 10  ASSAULT 1ST DEGREE OR ATTEMPT - SERIOUS PHYSIC...       13A   Person
# 11  ASSAULT 1ST DEGREE OR ATTEMPT - SERIOUS PHYSIC...       13A   Person
# 12  ASSAULT 1ST DEGREE OR ATTEMPT - SERIOUS PHYSIC...       13A   Person
#
#       NIBRSOffenseType  UCR_SRS CrimeGrade PrimaryLocation SecondaryLocation  \
# 9   Aggravated Assault      4.0        NaN         UTAH ST               NaN
# 10  Aggravated Assault      4.0        NaN         UTAH ST               NaN
# 11  Aggravated Assault      4.0        NaN         UTAH ST               NaN
# 12  Aggravated Assault      4.0        NaN         UTAH ST               NaN
#
#     District  Neighborhood NeighborhoodNum   Latitude  Longitude Supplemented  \
# 9        3.0  Marine Villa              18  38.595299 -90.226944          Yes
# 10       3.0  Marine Villa              18  38.595299 -90.226944          Yes
# 11       3.0  Marine Villa              18  38.595299 -90.226944          Yes
# 12       3.0  Marine Villa              18  38.595299 -90.226944          Yes
#
#                  SupplementDate  VictimNum FirearmUsed  \
# 9   2024-01-22 10:27:05.5130000   367377.0         Yes
# 10  2024-01-22 10:27:05.5130000   367378.0         Yes
# 11  2024-01-22 10:27:05.5130000   367379.0         Yes
# 12  2024-01-22 10:27:05.5130000   367380.0         Yes
#
#                               IncidentNature
# 9   Aggravated Assault - Shooting - Criminal
# 10  Aggravated Assault - Shooting - Criminal
# 11  Aggravated Assault - Shooting - Criminal
# 12  Aggravated Assault - Shooting - Criminal

# %%
new_df = df[df['Supplemented'] != 'Yes']
new_df
# Out:
#       IncidentNum IncidentDate TimeOccurred  \
# 258      22036250   2022-08-09          NaN
# 268      22037793   2022-08-16          NaN
# 727      23037984   2023-08-18          NaN
# 955      23049939   2023-10-22          NaN
# 1603     23058875   2023-12-28          NaN
# ...           ...          ...          ...
# 5870     24007184   2024-01-25     12:00:00
# 5871     24007205   2024-01-31     00:01:00
# 5872     24007385   2024-01-26     11:00:00
# 5873     24007544   2024-01-22     12:00:00
# 5874     24007571   2024-01-29     07:29:00
#
#                                        SLMPDOffense NIBRSCode     NIBRSCat  \
# 258                              UNFOUNDED INCIDENT       NaN          NaN
# 268                              UNFOUNDED INCIDENT       NaN          NaN
# 727                              UNFOUNDED INCIDENT       NaN          NaN
# 955                              UNFOUNDED INCIDENT       NaN          NaN
# 1603                             UNFOUNDED INCIDENT       NaN          NaN
# ...                                             ...       ...          ...
# 5870    STEALING UNDER $150 (PETTY LARCENY - OTHER)       23H     Property
# 5871  DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290     Property
# 5872                                       STEALING       23D     Property
# 5873  LEAVING THE SCENE OF A MOTOR VEHICLE ACCIDENT       90Z  Unspecified
# 5874    STEALING UNDER $150 (PETTY LARCENY - OTHER)       23H     Property
#
#                               NIBRSOffenseType  UCR_SRS CrimeGrade  \
# 258                                        NaN      NaN        NaN
# 268                                        NaN      NaN        NaN
# 727                                        NaN      NaN        NaN
# 955                                        NaN      NaN        NaN
# 1603                                       NaN      NaN        NaN
# ...                                        ...      ...        ...
# 5870                         All Other Larceny      6.0        NaN
# 5871  Destruction/Damage/Vandalism of Property      NaN        NaN
# 5872                       Theft From Building      6.0          F
# 5873                        All Other Offenses      NaN        NaN
# 5874                         All Other Larceny      6.0        NaN
#
#           PrimaryLocation SecondaryLocation  District      Neighborhood  \
# 258                   NaN               NaN       NaN               NaN
# 268                   NaN               NaN       NaN               NaN
# 727                   NaN               NaN       NaN               NaN
# 955                   NaN               NaN       NaN               NaN
# 1603                  NaN               NaN       NaN               NaN
# ...                   ...               ...       ...               ...
# 5870   5118 WATERMAN BLVD               NaN       5.0  Central West End
# 5871      7208 N BROADWAY               NaN       6.0  North Riverfront
# 5872  4021 LACLEDE AVENUE               NaN       5.0  Central West End
# 5873   6014 MARMADUKE AVE               NaN       2.0   Clifton Heights
# 5874          ACADEMY AVE         PAGE BLVD       5.0           Academy
#
#      NeighborhoodNum   Latitude  Longitude Supplemented  \
# 258              NaN        NaN        NaN          NaN
# 268              NaN        NaN        NaN          NaN
# 727              NaN        NaN        NaN          NaN
# 955              NaN        NaN        NaN          NaN
# 1603             NaN        NaN        NaN          NaN
# ...              ...        ...        ...          ...
# 5870              38  38.648258 -90.268370           No
# 5871              79  38.631053 -90.187720           No
# 5872              38  38.637080 -90.244946           No
# 5873              11  38.609736 -90.290430           No
# 5874              51  38.657860 -90.266113           No
#
#                    SupplementDate  VictimNum FirearmUsed  \
# 258   2024-01-18 23:46:31.4930000        NaN         NaN
# 268   2024-01-06 12:01:13.6100000        NaN         NaN
# 727   2024-01-09 08:04:53.7170000        NaN         NaN
# 955   2024-01-18 00:26:55.5770000        NaN         NaN
# 1603  2024-01-24 23:05:39.1070000        NaN         NaN
# ...                           ...        ...         ...
# 5870                          NaN        NaN          No
# 5871                          NaN        NaN          No
# 5872                          NaN        NaN          No
# 5873                          NaN        NaN          No
# 5874                          NaN        NaN          No
#
#                           IncidentNature
# 258                                  NaN
# 268                                  NaN
# 727                                  NaN
# 955                                  NaN
# 1603                                 NaN
# ...                                  ...
# 5870                  Larceny - Criminal
# 5871  Destruction of Property - Criminal
# 5872                  Larceny - Criminal
# 5873     Offenses - All Other - Criminal
# 5874                  Larceny - Criminal
#
# [2026 rows x 21 columns]

# %%
unfound_df = new_df[new_df['SLMPDOffense'] == 'UNFOUNDED INCIDENT']
unfound_df
# Out:
#       IncidentNum IncidentDate TimeOccurred        SLMPDOffense NIBRSCode  \
# 258      22036250   2022-08-09          NaN  UNFOUNDED INCIDENT       NaN
# 268      22037793   2022-08-16          NaN  UNFOUNDED INCIDENT       NaN
# 727      23037984   2023-08-18          NaN  UNFOUNDED INCIDENT       NaN
# 955      23049939   2023-10-22          NaN  UNFOUNDED INCIDENT       NaN
# 1603     23058875   2023-12-28          NaN  UNFOUNDED INCIDENT       NaN
# 1729     23059261   2023-12-31          NaN  UNFOUNDED INCIDENT       NaN
# 1758     23059329   2023-12-31          NaN  UNFOUNDED INCIDENT       NaN
# 1765     23059341   2023-12-31          NaN  UNFOUNDED INCIDENT       NaN
# 2007     24000269   2024-01-01          NaN  UNFOUNDED INCIDENT       NaN
# 2103     24000397   2023-12-30          NaN  UNFOUNDED INCIDENT       NaN
# 2157     24000452   2024-01-03          NaN  UNFOUNDED INCIDENT       NaN
# 2197     24000500   2024-01-03          NaN  UNFOUNDED INCIDENT       NaN
# 2200     24000506   2023-12-24          NaN  UNFOUNDED INCIDENT       NaN
# 2231     24000558   2024-01-01          NaN  UNFOUNDED INCIDENT       NaN
# 2280     24000602   2023-01-04          NaN  UNFOUNDED INCIDENT       NaN
# 2302     24000632   2024-01-02          NaN  UNFOUNDED INCIDENT       NaN
# 2554     24000924   2024-01-04          NaN  UNFOUNDED INCIDENT       NaN
# 2626     24001001   2024-01-06          NaN  UNFOUNDED INCIDENT       NaN
# 2822     24001187   2024-01-02          NaN  UNFOUNDED INCIDENT       NaN
# 3493     24001963   2024-01-13          NaN  UNFOUNDED INCIDENT       NaN
# 3543     24002029   2024-01-09          NaN  UNFOUNDED INCIDENT       NaN
# 3549     24002035   2024-01-14          NaN  UNFOUNDED INCIDENT       NaN
# 3737     24002296   2024-01-15          NaN  UNFOUNDED INCIDENT       NaN
# 3853     24002440   2024-01-17          NaN  UNFOUNDED INCIDENT       NaN
# 3893     24002489   2024-01-17          NaN  UNFOUNDED INCIDENT       NaN
# 3949     24002539   2024-01-18          NaN  UNFOUNDED INCIDENT       NaN
# 3994     24002595   2024-01-10          NaN  UNFOUNDED INCIDENT       NaN
# 4105     24002744   2024-01-19          NaN  UNFOUNDED INCIDENT       NaN
# 4197     24002838   2024-01-20          NaN  UNFOUNDED INCIDENT       NaN
# 4265     24002915   2024-01-20          NaN  UNFOUNDED INCIDENT       NaN
# 4322     24002985   2024-01-18          NaN  UNFOUNDED INCIDENT       NaN
# 4417     24003120   2024-01-22          NaN  UNFOUNDED INCIDENT       NaN
# 4492     24003203   2024-01-23          NaN  UNFOUNDED INCIDENT       NaN
# 4812     24003529   2023-12-23          NaN  UNFOUNDED INCIDENT       NaN
# 5478     24004239   2024-01-30          NaN  UNFOUNDED INCIDENT       NaN
# 5665     24004429   2024-01-30          NaN  UNFOUNDED INCIDENT       NaN
# 5740     24004521   2024-01-31          NaN  UNFOUNDED INCIDENT       NaN
# 5763     24004561   2024-01-29          NaN  UNFOUNDED INCIDENT       NaN
#
#      NIBRSCat NIBRSOffenseType  UCR_SRS CrimeGrade PrimaryLocation  \
# 258       NaN              NaN      NaN        NaN             NaN
# 268       NaN              NaN      NaN        NaN             NaN
# 727       NaN              NaN      NaN        NaN             NaN
# 955       NaN              NaN      NaN        NaN             NaN
# 1603      NaN              NaN      NaN        NaN             NaN
# 1729      NaN              NaN      NaN        NaN             NaN
# 1758      NaN              NaN      NaN        NaN             NaN
# 1765      NaN              NaN      NaN        NaN             NaN
# 2007      NaN              NaN      NaN        NaN             NaN
# 2103      NaN              NaN      NaN        NaN             NaN
# 2157      NaN              NaN      NaN        NaN             NaN
# 2197      NaN              NaN      NaN        NaN             NaN
# 2200      NaN              NaN      NaN        NaN             NaN
# 2231      NaN              NaN      NaN        NaN             NaN
# 2280      NaN              NaN      NaN        NaN             NaN
# 2302      NaN              NaN      NaN        NaN             NaN
# 2554      NaN              NaN      NaN        NaN             NaN
# 2626      NaN              NaN      NaN        NaN             NaN
# 2822      NaN              NaN      NaN        NaN             NaN
# 3493      NaN              NaN      NaN        NaN             NaN
# 3543      NaN              NaN      NaN        NaN             NaN
# 3549      NaN              NaN      NaN        NaN             NaN
# 3737      NaN              NaN      NaN        NaN             NaN
# 3853      NaN              NaN      NaN        NaN             NaN
# 3893      NaN              NaN      NaN        NaN             NaN
# 3949      NaN              NaN      NaN        NaN             NaN
# 3994      NaN              NaN      NaN        NaN             NaN
# 4105      NaN              NaN      NaN        NaN             NaN
# 4197      NaN              NaN      NaN        NaN             NaN
# 4265      NaN              NaN      NaN        NaN             NaN
# 4322      NaN              NaN      NaN        NaN             NaN
# 4417      NaN              NaN      NaN        NaN             NaN
# 4492      NaN              NaN      NaN        NaN             NaN
# 4812      NaN              NaN      NaN        NaN             NaN
# 5478      NaN              NaN      NaN        NaN             NaN
# 5665      NaN              NaN      NaN        NaN             NaN
# 5740      NaN              NaN      NaN        NaN             NaN
# 5763      NaN              NaN      NaN        NaN             NaN
#
#      SecondaryLocation  District Neighborhood NeighborhoodNum  Latitude  \
# 258                NaN       NaN          NaN             NaN       NaN
# 268                NaN       NaN          NaN             NaN       NaN
# 727                NaN       NaN          NaN             NaN       NaN
# 955                NaN       NaN          NaN             NaN       NaN
# 1603               NaN       NaN          NaN             NaN       NaN
# 1729               NaN       NaN          NaN             NaN       NaN
# 1758               NaN       NaN          NaN             NaN       NaN
# 1765               NaN       NaN          NaN             NaN       NaN
# 2007               NaN       NaN          NaN             NaN       NaN
# 2103               NaN       NaN          NaN             NaN       NaN
# 2157               NaN       NaN          NaN             NaN       NaN
# 2197               NaN       NaN          NaN             NaN       NaN
# 2200               NaN       NaN          NaN             NaN       NaN
# 2231               NaN       NaN          NaN             NaN       NaN
# 2280               NaN       NaN          NaN             NaN       NaN
# 2302               NaN       NaN          NaN             NaN       NaN
# 2554               NaN       NaN          NaN             NaN       NaN
# 2626               NaN       NaN          NaN             NaN       NaN
# 2822               NaN       NaN          NaN             NaN       NaN
# 3493               NaN       NaN          NaN             NaN       NaN
# 3543               NaN       NaN          NaN             NaN       NaN
# 3549               NaN       NaN          NaN             NaN       NaN
# 3737               NaN       NaN          NaN             NaN       NaN
# 3853               NaN       NaN          NaN             NaN       NaN
# 3893               NaN       NaN          NaN             NaN       NaN
# 3949               NaN       NaN          NaN             NaN       NaN
# 3994               NaN       NaN          NaN             NaN       NaN
# 4105               NaN       NaN          NaN             NaN       NaN
# 4197               NaN       NaN          NaN             NaN       NaN
# 4265               NaN       NaN          NaN             NaN       NaN
# 4322               NaN       NaN          NaN             NaN       NaN
# 4417               NaN       NaN          NaN             NaN       NaN
# 4492               NaN       NaN          NaN             NaN       NaN
# 4812               NaN       NaN          NaN             NaN       NaN
# 5478               NaN       NaN          NaN             NaN       NaN
# 5665               NaN       NaN          NaN             NaN       NaN
# 5740               NaN       NaN          NaN             NaN       NaN
# 5763               NaN       NaN          NaN             NaN       NaN
#
#       Longitude Supplemented               SupplementDate  VictimNum  \
# 258         NaN          NaN  2024-01-18 23:46:31.4930000        NaN
# 268         NaN          NaN  2024-01-06 12:01:13.6100000        NaN
# 727         NaN          NaN  2024-01-09 08:04:53.7170000        NaN
# 955         NaN          NaN  2024-01-18 00:26:55.5770000        NaN
# 1603        NaN          NaN  2024-01-24 23:05:39.1070000        NaN
# 1729        NaN          NaN  2024-01-12 08:36:23.0530000        NaN
# 1758        NaN          NaN  2024-01-11 18:27:59.4200000        NaN
# 1765        NaN          NaN  2024-01-04 14:13:49.0570000        NaN
# 2007        NaN          NaN  2024-01-04 15:42:22.6500000        NaN
# 2103        NaN          NaN  2024-01-05 15:16:44.6000000        NaN
# 2157        NaN          NaN                          NaN        NaN
# 2197        NaN          NaN                          NaN        NaN
# 2200        NaN          NaN  2024-01-11 18:21:47.6400000        NaN
# 2231        NaN          NaN  2024-01-12 17:58:35.5400000        NaN
# 2280        NaN          NaN  2024-01-04 14:23:57.4270000        NaN
# 2302        NaN          NaN  2024-01-15 12:30:33.7700000        NaN
# 2554        NaN          NaN                          NaN        NaN
# 2626        NaN          NaN  2024-01-07 17:50:11.6070000        NaN
# 2822        NaN          NaN                          NaN        NaN
# 3493        NaN          NaN  2024-01-19 11:51:44.5100000        NaN
# 3543        NaN          NaN                          NaN        NaN
# 3549        NaN          NaN                          NaN        NaN
# 3737        NaN          NaN  2024-01-26 14:58:20.9200000        NaN
# 3853        NaN          NaN  2024-01-22 23:32:13.8570000        NaN
# 3893        NaN          NaN                          NaN        NaN
# 3949        NaN          NaN  2024-01-23 21:07:57.0000000        NaN
# 3994        NaN          NaN  2024-02-12 13:31:44.0000000        NaN
# 4105        NaN          NaN  2024-01-23 08:36:04.8830000        NaN
# 4197        NaN          NaN  2024-01-29 11:06:31.5900000        NaN
# 4265        NaN          NaN                          NaN        NaN
# 4322        NaN          NaN  2024-02-20 14:16:46.9470000        NaN
# 4417        NaN          NaN  2024-02-05 23:40:52.6870000        NaN
# 4492        NaN          NaN                          NaN        NaN
# 4812        NaN          NaN  2024-01-27 13:13:28.0830000        NaN
# 5478        NaN          NaN  2024-02-05 11:01:05.9000000        NaN
# 5665        NaN          NaN                          NaN        NaN
# 5740        NaN          NaN                          NaN        NaN
# 5763        NaN          NaN  2024-02-13 09:01:45.9200000        NaN
#
#      FirearmUsed IncidentNature
# 258          NaN            NaN
# 268          NaN            NaN
# 727          NaN            NaN
# 955          NaN            NaN
# 1603         NaN            NaN
# 1729         NaN            NaN
# 1758         NaN            NaN
# 1765         NaN            NaN
# 2007         NaN            NaN
# 2103         NaN            NaN
# 2157         NaN            NaN
# 2197         NaN            NaN
# 2200         NaN            NaN
# 2231         NaN            NaN
# 2280         NaN            NaN
# 2302         NaN            NaN
# 2554         NaN            NaN
# 2626         NaN            NaN
# 2822         NaN            NaN
# 3493         NaN            NaN
# 3543         NaN            NaN
# 3549         NaN            NaN
# 3737         NaN            NaN
# 3853         NaN            NaN
# 3893         NaN            NaN
# 3949         NaN            NaN
# 3994         NaN            NaN
# 4105         NaN            NaN
# 4197         NaN            NaN
# 4265         NaN            NaN
# 4322         NaN            NaN
# 4417         NaN            NaN
# 4492         NaN            NaN
# 4812         NaN            NaN
# 5478         NaN            NaN
# 5665         NaN            NaN
# 5740         NaN            NaN
# 5763         NaN            NaN

# %%
unfound_df['IncidentNum'].value_counts()
# Out:
# IncidentNum
# 22036250    1
# 24002838    1
# 24002035    1
# 24002296    1
# 24002440    1
# 24002489    1
# 24002539    1
# 24002595    1
# 24002744    1
# 24002915    1
# 22037793    1
# 24002985    1
# 24003120    1
# 24003203    1
# 24003529    1
# 24004239    1
# 24004429    1
# 24004521    1
# 24002029    1
# 24001963    1
# 24001187    1
# 24001001    1
# 23037984    1
# 23049939    1
# 23058875    1
# 23059261    1
# 23059329    1
# 23059341    1
# 24000269    1
# 24000397    1
# 24000452    1
# 24000500    1
# 24000506    1
# 24000558    1
# 24000602    1
# 24000632    1
# 24000924    1
# 24004561    1
# Name: count, dtype: int64

# %%
# Connect to SQLite database
conn = sqlite3.connect('test_db.db')
cursor = conn.cursor()

# %%
# Read the CSV file into a DataFrame
new_data = df

# Prepare a list of tuples containing the data to update
update_data = []
for row in new_data.itertuples(index=False):

    cursor.execute('''
    
    
    ''')
    matches = cursor.fetchall()

    
    update_data.append((row.column1, row.column2, ..., row.id))

# Update existing rows in batch
# cursor.executemany("UPDATE crime_data SET column1=?, column2=?, ... WHERE id=?", update_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 7
#       5 update_data = []
#       6 for row in new_data.itertuples(index=False):
# ----> 7     update_data.append((row.column1, row.column2, ..., row.id))
#       9 # Update existing rows in batch
#      10 # cursor.executemany("UPDATE crime_data SET column1=?, column2=?, ... WHERE id=?", update_data)
#
# AttributeError: 'Pandas' object has no attribute 'column1'

# %%
for row in new_data.itertuples():
    row = row
row

# %%
conn.close()
